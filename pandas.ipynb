# %% [markdown]
# <a href="https://colab.research.google.com/github/AXUNDA/AXUNDA/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
labels = ["a","b","c"]

# %%
mylist = [1,2,3]

# %%
arr = np.array(mylist)

# %%
arr
# Out:
# array([1, 2, 3])

# %%
d = {"a":1,"b":2,"c":3}

# %%
pd.Series(mylist)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(mylist,labels)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4,5],index=["a",'b','c','d','e'])
ser1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
ser1['a':'d']
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
ser2 = pd.Series([4,7,3,5,5],index=["a",'b','cd','d','e'])

# %%
ser1 + ser2
# Out:
# a      5.0
# b      9.0
# c      NaN
# cd     NaN
# d      9.0
# e     10.0
# dtype: float64

# %%
from numpy.random import randn
from numpy import random
from pandas import DataFrame

# %%
random.seed(101)
rad_mat =randn(5,4)
#5 by 4 matrix

# %%
rad_mat
# Out:
# array([[ 2.70684984,  0.62813271,  0.90796945,  0.50382575],
#        [ 0.65111795, -0.31931804, -0.84807698,  0.60596535],
#        [-2.01816824,  0.74012206,  0.52881349, -0.58900053],
#        [ 0.18869531, -0.75887206, -0.93323722,  0.95505651],
#        [ 0.19079432,  1.97875732,  2.60596728,  0.68350889]])

# %%
df = DataFrame(rad_mat,'A B C D E'.split(),'F G H I'.split())
df
# Out:
#           F         G         H         I
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[['F','I']]
# Out:
#           F         I
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
df['NEW'] = df['F'] +df['I']

df
# Out:
#           F         G         H         I       NEW
# A  2.706850  0.628133  0.907969  0.503826  3.210676
# B  0.651118 -0.319318 -0.848077  0.605965  1.257083
# C -2.018168  0.740122  0.528813 -0.589001 -2.607169
# D  0.188695 -0.758872 -0.933237  0.955057  1.143752
# E  0.190794  1.978757  2.605967  0.683509  0.874303

# %%
df.drop('NEW',axis=1)
# Out:
#           F         G         H         I
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('NEW',axis=1,inplace=True)

# %%
df
# Out:
#           F         G         H         I
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.loc['A']
# Out:
# F    2.706850
# G    0.628133
# H    0.907969
# I    0.503826
# Name: A, dtype: float64

# %%
df.iloc[0]
# Out:
# F    2.706850
# G    0.628133
# H    0.907969
# I    0.503826
# Name: A, dtype: float64
